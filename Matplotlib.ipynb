# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
arr=np.arange(1,5)

# %%
arr1=np.arange(1,5)

# %%
plt.plot(arr,arr1)
plt.show()

# %%
plt.plot(arr,arr1)
plt.title('My graph')
plt.ylabel('Y-axis')
plt.xlabel('X-axis')
plt.show()
